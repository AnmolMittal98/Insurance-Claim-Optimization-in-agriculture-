# %%
# Importing all necessary libraries 
import cv2 
import os 
  
# Read the video from specified path 
cam = cv2.VideoCapture(r"C:\Users\98anm\Desktop\ANMOL\DATA SCIENCE 2\ML PROJECTS\minorp\farm5.mp4") 
  
try: 
      
    # creating a folder named data 
    if not os.path.exists('data'): 
        os.makedirs('data') 
  
# if not created then raise error 
except OSError: 
    print ('Error: Creating directory of data') 
  
# frame 
currentframe = 0
  
while(True): 
      
    # reading from frame 
    ret,frame = cam.read() 
  
    if ret: 
        # if video is still left continue creating images 
        name = './data/framefive' + str(currentframe) + '.jpg'
        print ('Creating...' + name) 
  
        # writing the extracted images 
        cv2.imwrite(name, frame) 
  
        # increasing counter so that it will 
        # show how many frames are created 
        currentframe += 1
    else: 
        break
  
# Release all space and windows once done 
cam.release() 
cv2.destroyAllWindows()
# Out:
# Creating..../data/framefive0.jpg
# Creating..../data/framefive1.jpg
# Creating..../data/framefive2.jpg
# Creating..../data/framefive3.jpg
# Creating..../data/framefive4.jpg
# Creating..../data/framefive5.jpg
# Creating..../data/framefive6.jpg
# Creating..../data/framefive7.jpg
# Creating..../data/framefive8.jpg
# Creating..../data/framefive9.jpg
# Creating..../data/framefive10.jpg
# Creating..../data/framefive11.jpg
# Creating..../data/framefive12.jpg
# Creating..../data/framefive13.jpg
# Creating..../data/framefive14.jpg
# Creating..../data/framefive15.jpg
# Creating..../data/framefive16.jpg
# Creating..../data/framefive17.jpg
# Creating..../data/framefive18.jpg
# Creating..../data/framefive19.jpg
# Creating..../data/framefive20.jpg
# Creating..../data/framefive21.jpg
# Creating..../data/framefive22.jpg
# Creating..../data/framefive23.jpg
# Creating..../data/framefive24.jpg
# Creating..../data/framefive25.jpg
# Creating..../data/framefive26.jpg
# Creating..../data/framefive27.jpg
# Creating..../data/framefive28.jpg
# Creating..../data/framefive29.jpg
# Creating..../data/framefive30.jpg
# Creating..../data/framefive31.jpg
# Creating..../data/framefive32.jpg
# Creating..../data/framefive33.jpg
# Creating..../data/framefive34.jpg
# Creating..../data/framefive35.jpg
# Creating..../data/framefive36.jpg
# Creating..../data/framefive37.jpg
# Creating..../data/framefive38.jpg
# Creating..../data/framefive39.jpg
# Creating..../data/framefive40.jpg
# Creating..../data/framefive41.jpg
# Creating..../data/framefive42.jpg
# Creating..../data/framefive43.jpg
# Creating..../data/framefive44.jpg
# Creating..../data/framefive45.jpg
# Creating..../data/framefive46.jpg
# Creating..../data/framefive47.jpg
# Creating..../data/framefive48.jpg
# Creating..../data/framefive49.jpg
# Creating..../data/framefive50.jpg
# Creating..../data/framefive51.jpg
# Creating..../data/framefive52.jpg
# Creating..../data/framefive53.jpg
# Creating..../data/framefive54.jpg
# Creating..../data/framefive55.jpg
# Creating..../data/framefive56.jpg
# Creating..../data/framefive57.jpg
# Creating..../data/framefive58.jpg
# Creating..../data/framefive59.jpg
# Creating..../data/framefive60.jpg
# Creating..../data/framefive61.jpg
# Creating..../data/framefive62.jpg
# Creating..../data/framefive63.jpg
# Creating..../data/framefive64.jpg
# Creating..../data/framefive65.jpg
# Creating..../data/framefive66.jpg
# Creating..../data/framefive67.jpg
# Creating..../data/framefive68.jpg
# Creating..../data/framefive69.jpg
# Creating..../data/framefive70.jpg
# Creating..../data/framefive71.jpg
# Creating..../data/framefive72.jpg
# Creating..../data/framefive73.jpg
# Creating..../data/framefive74.jpg
# Creating..../data/framefive75.jpg
# Creating..../data/framefive76.jpg
# Creating..../data/framefive77.jpg
# Creating..../data/framefive78.jpg
# Creating..../data/framefive79.jpg
# Creating..../data/framefive80.jpg
# Creating..../data/framefive81.jpg
# Creating..../data/framefive82.jpg
# Creating..../data/framefive83.jpg
# Creating..../data/framefive84.jpg
# Creating..../data/framefive85.jpg
# Creating..../data/framefive86.jpg
# Creating..../data/framefive87.jpg
# Creating..../data/framefive88.jpg
# Creating..../data/framefive89.jpg
# Creating..../data/framefive90.jpg
# Creating..../data/framefive91.jpg
# Creating..../data/framefive92.jpg
# Creating..../data/framefive93.jpg
# Creating..../data/framefive94.jpg
# Creating..../data/framefive95.jpg
# Creating..../data/framefive96.jpg
# Creating..../data/framefive97.jpg
# Creating..../data/framefive98.jpg
# Creating..../data/framefive99.jpg
# Creating..../data/framefive100.jpg
# Creating..../data/framefive101.jpg
# Creating..../data/framefive102.jpg
# Creating..../data/framefive103.jpg
# Creating..../data/framefive104.jpg
# Creating..../data/framefive105.jpg
# Creating..../data/framefive106.jpg
# Creating..../data/framefive107.jpg
# Creating..../data/framefive108.jpg
# Creating..../data/framefive109.jpg
# Creating..../data/framefive110.jpg
# Creating..../data/framefive111.jpg
# Creating..../data/framefive112.jpg
# Creating..../data/framefive113.jpg
# Creating..../data/framefive114.jpg
# Creating..../data/framefive115.jpg
# Creating..../data/framefive116.jpg
# Creating..../data/framefive117.jpg
# Creating..../data/framefive118.jpg
# Creating..../data/framefive119.jpg
# Creating..../data/framefive120.jpg
# Creating..../data/framefive121.jpg
# Creating..../data/framefive122.jpg
# Creating..../data/framefive123.jpg
# Creating..../data/framefive124.jpg
# Creating..../data/framefive125.jpg
# Creating..../data/framefive126.jpg
# Creating..../data/framefive127.jpg
# Creating..../data/framefive128.jpg
# Creating..../data/framefive129.jpg
# Creating..../data/framefive130.jpg
# Creating..../data/framefive131.jpg
# Creating..../data/framefive132.jpg
# Creating..../data/framefive133.jpg
# Creating..../data/framefive134.jpg
# Creating..../data/framefive135.jpg
# Creating..../data/framefive136.jpg
# Creating..../data/framefive137.jpg
# Creating..../data/framefive138.jpg
# Creating..../data/framefive139.jpg
# Creating..../data/framefive140.jpg
# Creating..../data/framefive141.jpg
# Creating..../data/framefive142.jpg
# Creating..../data/framefive143.jpg
# Creating..../data/framefive144.jpg
# Creating..../data/framefive145.jpg
# Creating..../data/framefive146.jpg
# Creating..../data/framefive147.jpg
# Creating..../data/framefive148.jpg
# Creating..../data/framefive149.jpg
# Creating..../data/framefive150.jpg
# Creating..../data/framefive151.jpg
# Creating..../data/framefive152.jpg
# Creating..../data/framefive153.jpg
# Creating..../data/framefive154.jpg
# Creating..../data/framefive155.jpg
# Creating..../data/framefive156.jpg
# Creating..../data/framefive157.jpg
# Creating..../data/framefive158.jpg
# Creating..../data/framefive159.jpg
# Creating..../data/framefive160.jpg
# Creating..../data/framefive161.jpg
# Creating..../data/framefive162.jpg
# Creating..../data/framefive163.jpg
# Creating..../data/framefive164.jpg
# Creating..../data/framefive165.jpg
# Creating..../data/framefive166.jpg
# Creating..../data/framefive167.jpg
# Creating..../data/framefive168.jpg
# Creating..../data/framefive169.jpg
# Creating..../data/framefive170.jpg
# Creating..../data/framefive171.jpg
# Creating..../data/framefive172.jpg
# Creating..../data/framefive173.jpg
# Creating..../data/framefive174.jpg
# Creating..../data/framefive175.jpg
# Creating..../data/framefive176.jpg
# Creating..../data/framefive177.jpg
# Creating..../data/framefive178.jpg
# Creating..../data/framefive179.jpg
# Creating..../data/framefive180.jpg
# Creating..../data/framefive181.jpg
# Creating..../data/framefive182.jpg
# Creating..../data/framefive183.jpg
# Creating..../data/framefive184.jpg
# Creating..../data/framefive185.jpg
# Creating..../data/framefive186.jpg
# Creating..../data/framefive187.jpg
# Creating..../data/framefive188.jpg
# Creating..../data/framefive189.jpg
# Creating..../data/framefive190.jpg
# Creating..../data/framefive191.jpg
# Creating..../data/framefive192.jpg
# Creating..../data/framefive193.jpg
# Creating..../data/framefive194.jpg
# Creating..../data/framefive195.jpg
# Creating..../data/framefive196.jpg
# Creating..../data/framefive197.jpg
# Creating..../data/framefive198.jpg
# Creating..../data/framefive199.jpg
# Creating..../data/framefive200.jpg
# Creating..../data/framefive201.jpg
# Creating..../data/framefive202.jpg
# Creating..../data/framefive203.jpg
# Creating..../data/framefive204.jpg
# Creating..../data/framefive205.jpg
# Creating..../data/framefive206.jpg
