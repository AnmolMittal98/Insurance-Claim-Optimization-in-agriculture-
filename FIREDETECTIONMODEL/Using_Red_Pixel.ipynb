# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
from PIL import Image
import io
import cv2
import os
import sys
import time
import glob
import csv
from skimage.morphology import reconstruction

# %%
files = []
for file1 in glob.glob(r'C:\Users\98anm\Desktop\MINOR\FIRE\*'):
    for file2 in glob.glob(file1+"\*.jpg"):
        files.append([file2,file1])

# %%
len(files)
# Out:
# 106

# %%
x=0
for i in range(len(files)):
    frame=cv2.imread(files[i][0])
    print(i)
    blur = cv2.GaussianBlur(frame, (21, 21), 0)
    hsv = cv2.cvtColor(blur, cv2.COLOR_BGR2HSV)
 
    lower = [18, 50, 50]
    upper = [35, 255, 255]
    lower = np.array(lower, dtype="uint8")
    upper = np.array(upper, dtype="uint8")
    mask = cv2.inRange(hsv, lower, upper)
    
    output = cv2.bitwise_and(frame, hsv, mask=mask)
    no_red = cv2.countNonZero(mask)
    cv2.imshow("output", output)
    #print("output:", frame)
    if int(no_red) > 20000:
        print ('Fire detected')
    #print(int(no_red))
   #print("output:".format(mask))
    print("Done!!!")
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break
 
cv2.destroyAllWindows()
# Out:
# 0
# Done!!!
# 1
# Done!!!
# 2
# Done!!!
# 3
# Fire detected
# Done!!!
# 4
# Fire detected
# Done!!!
# 5
# Done!!!
# 6
# Done!!!
# 7
# Done!!!
# 8
# Done!!!
# 9
# Done!!!
# 10
# Done!!!
# 11
# Done!!!
# 12
# Fire detected
# Done!!!
# 13
# Done!!!
# 14
# Fire detected
# Done!!!
# 15
# Fire detected
# Done!!!
# 16
# Done!!!
# 17
# Done!!!
# 18
# Done!!!
# 19
# Done!!!
# 20
# Fire detected
# Done!!!
# 21
# Fire detected
# Done!!!
# 22
# Fire detected
# Done!!!
# 23
# Fire detected
# Done!!!
# 24
# Fire detected
# Done!!!
# 25
# Done!!!
# 26
# Fire detected
# Done!!!
# 27
# Done!!!
# 28
# Fire detected
# Done!!!
# 29
# Fire detected
# Done!!!
# 30
# Fire detected
# Done!!!
# 31
# Done!!!
# 32
# Fire detected
# Done!!!
# 33
# Fire detected
# Done!!!
# 34
# Done!!!
# 35
# Fire detected
# Done!!!
# 36
# Done!!!
# 37
# Fire detected
# Done!!!
# 38
# Fire detected
# Done!!!
# 39
# Fire detected
# Done!!!
# 40
# Done!!!
# 41
# Fire detected
# Done!!!
# 42
# Fire detected
# Done!!!
# 43
# ...

# %%
plt.imshow(cv2.imread(files[4][0]))

# %%
frame=cv2.imread(files[4][0])  
blur = cv2.GaussianBlur(frame, (21, 21), 0)
hsv = cv2.cvtColor(blur, cv2.COLOR_BGR2HSV)
 
lower = [18, 50, 50]
upper = [35, 255, 255]
lower = np.array(lower, dtype="uint8")
upper = np.array(upper, dtype="uint8")
mask = cv2.inRange(hsv, lower, upper) 

output = cv2.bitwise_and(frame, hsv, mask=mask)
cv2.imshow("output", output)
if cv2.waitKey(1) & 0xFF == ord('q'):
    cv2.destroyAllWindows()
